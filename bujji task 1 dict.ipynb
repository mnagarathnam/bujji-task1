# %%
 {
    "eventHeader":{
         "id":"fe578fdd-233a-4c28-9bdc-cc58b9da2f47",
         "time":1711630848066,
         "type":"com.kroger.desp.events.fullfillment.TrolleycreatedEvent",
         "source":"PSC",
         "correlationId":"34c5baf8-4f68-49fe-8130-792d72d878c7"
    },
     "requestId": "869331102571051",
     "locationId":"01100490",
     "trolleys":[
         {
             "uuid":"738b5238-41d2-4a9a-abcb-0dccff09080d",
             :"containers":[
                  {
                      "uuid":"3c617939-f87b-4f86-8671-7570f34bc918",
                      "items":[
                          {
                              "upc":"0008266650080",
                              "routestep":28,
                              "routelocation": "7.L.12.1.6"
                          },
                          {
                              "upc":"0060265217186",
                              "routestep":14,
                              "routelocation":"6.L.3.4.2"
                          },
                          {
                              "upc":"0009370962001",
                              "routestep":12,
                              "routelocation":"8.R.16.7.9"
                          },
                          {
                              "upc":"0002412601814",
                              "routestep":36,
                              "routelocation":"2.R.7.5.1"
                          },
                          {
                              "upc":"0001300000640",
                              "routestep":34,
                              "routelocation":"2.L.11.2.1"
                          },
                          {
                              "upc":"0001111010996",
                              "routestep":27,
                              "routelocation":"7.R.14.1.5"
                          },
                          {
                              "upc":"0002100061",
                              "routestep":41,
                              "routelocation":"3.L.6.1.2"
                          },
                          {
                              "upc":"0002412601711",
                              "routestep":35,
                              "routelocation":"2.R.7.1.1"
                          },
                          {
                              "upc":"0007225002108",
                              "routestep":32,
                              "routelocation":"2.R.11.5.3"
                          },
                          {
                              "upc":"0004900006102",
                              "routestep":4,
                              "routelocation":"13.L.7.4.1"
                          },
                          {
                              "upc":"0001111011972",
                              "routestep":18,
                              "routelocation":"4.R.10.5.4"
                          }
                      ],
                          "orderId":"pick_creation_dsw_1240884410294648901"
                },
                {
                    "uuid":"2d0721ab-1368425a-9367-c618709b5e3c",
                    "items":[
                        {
                              "upc":"0001111011045",
                              "routestep":39,
                              "routelocation":"2.R.3.4.5"
                          },
                          {
                              "upc":"0001111086329",
                              "routestep":26,
                              "routelocation":"7.L.15.6.5"
                          },
                          {
                              "upc":"0066283450104",
                              "routestep":1,
                              "routelocation":"26.L.5.4.3"
                          },
                          {
                              "upc":"0081075701008",
                              "routestep":42,
                              "routelocation":"3.L.7.3.5"
                          },
                          {
                              "upc":"0007092047633",
                              "routestep":13,
                              "routelocation":"8.L.12.5.3"
                          }
                      ],
                      "orderId":"pick_creation_dsw_1240884481855971901"
                   },
                   {
                       "uuid":"7e513bf2-42a0-465b-965f-bd9caf758093",
                       "items":[
                           {
                              "upc":"0001111091760",
                              "routestep":50,
                              "routelocation":"produce1..0.."
                          },
                          {
                              "upc":"0004900000548",
                              "routestep":2,
                              "routelocation":"13.L.1.5.1"
                          },
                          {
                              "upc":"0004900004665",
                              "routestep":3,
                              "routelocation":"13.L.4.5.1"
                          }
                       ],
                       "orderId":"pick_creation_dsw_1240884481855971901"
                   },
                   {
                      "uuid":"ce8a553--5596-4f54-9dd4-26e6b5d08556",
                      "items":[
                          {
                              "upc":"0008266650080",
                              "routestep":28,
                              "routelocation":"7.L.12.1.6"
                          },
                          {
                              "upc":"0060265217186",
                              "routestep":14,
                              "routelocation":"6.L.3.4.2"
                          },
                          {
                              "upc":"0009370962001",
                              "routestep":12,
                              "routelocation":"8.R.16.7.9"
                          },
                          {
                              "upc":"0001111060179",
                              "routestep":47,
                              "routelocation":"produce1..0.."
                          },
                          {
                              "upc":"0001111000918",
                              "routestep":30,
                              "routelocation":"2.R.15.4.5"
                          },
                          {
                              "upc":"0004749571065",
                              "routestep":11,
                              "routelocation":"8.R.18.3.7"
                          },
                          {
                              "upc":"0001111090108",
                              "routestep":7,
                              "routelocation":"9.R.20.4.3"
                          }
                      ],
                      "orderId":"pick_creation_dsw_1240884410294648901"
                   },
                   {
                      "uuid":"2d0721ab-1368-425a-9367-c618709b5e3c",
                      "items":[
                          {
                              "upc":"0001111011045",
                              "routestep":39,
                              "routelocation":"2.R.3.4.5"
                          },
                          {
                              "upc":"0001111086329",
                              "routestep":26,
                              "routelocation":"7.L.15.6.5"
                          },
                          {
                             "upc":"0066283450104",
                              "routestep":1,
                              "routelocation":"26.L.5.4.3"
                          },
                          {
                              "upc":"0081075701008",
                              "routestep":42,
                              "routelocation":"3.L.7.3.5"
                          },
                          {
                              "upc":"0004400007299",
                              "routestep":9,
                              "routelocation":"8.R.22.6.1"
                          }
                      ],
                      "orderId":"pick_creation_dsw_1240884410294648901"
                   },
                   {
                      "uuid":"4a1479bf-f0ac-47ab-b636-f76e1590c11d",
                      "items":[
                          { 
                              "upc":"0076211188812",
                              "routestep":8,
                              "routelocation":"7.L.15.6.5"
                          },
                          {
                              "upc":"0005150000693",
                              "routestep":38,
                              "routelocation":"2.R.4.3.4"
                          },
                          {
                              "upc":"00024000020000",
                              "routestep":22,
                              "routelocation":"4.R.20.1.7"
                          },
                          {
                              "upc":"0002412601814",
                              "routestep":36,
                              "routelocation":"2.R.7.5.1"
                          }
                      ],
                      "orderId":"pick_creation_dsw_1240884537392457801"
                   },
                   {
                      "uuid":"ad65c334-beb6-48ed-ba1a-ff947eb054ee",
                      "items":[
                         {        
                              "upc":"0003940001974",
                              "routestep":20,
                              "routelocation":"4.R.16.4.2"
                          },
                          {
                              "upc":"0002430004101",
                              "routestep":29,
                              "routelocation":"2.R.17.."
                          },
                          {
                              "upc":"0001111071785",
                              "routestep":21,
                              "routelocation":"4.R.19.3.5"
                          },
                          {
                             "upc":"0000000004011",
                              "routestep":45,
                              "routelocation":"produce2..0.."
                          },
                          {
                              "upc":"0001111091760",
                              "routestep":51,
                              "routelocation":"produce1..0.."
                          },
                          {
                              "upc":"0002100064361",
                              "routestep":40,
                              "routelocation":"2.L.5.5.3"
                          },
                          {
                              "upc":"0001500004798",
                              "routestep":5,
                              "routelocation":"16.L.12.5.1"
                          },
                          {
                           
                              "upc":"0001111011694",
                              "routestep":15,
                              "routelocation":"5.R.1.5.3"
                          },
                          {
                              "upc":"0001111000323",
                              "routestep":23,
                              "routelocation":"5.L.16.2.14"
                          },
                          {
                              "upc":"0001111009176",
                              "routestep":16,
                              "routelocation":"4.R.1.5.3"
                          },
                          {
                              "upc":"0001111011486",
                              "routestep":31,
                              "routelocation":"2.R.13.1.1"
                          },
                          {
                           
                              "upc":"0003800022285",
                              "routestep":24,
                              "routelocation":"6.R.23.7.2"
                          }
                      ],
                      "orderId":"pick_creation_dsw_1240884603561582301"
                }
             ]
        }               
    ]
 }
Metadata:
